# %%
import spartan2.spartan as st

# %%
# set the computing engine
st.config(st.engine.SINGLEMACHINE)

# %%
# load graph data
tensor = st.loadTensor(name = "example", path = "inputData/", col_types = [int, int], hasvalue=0)
# Out:
# Info: Tensor is loaded
#            ----------------------
#              attr     |	2
#              values   |	0
#              nonzeros |	898

# %%
graph = tensor.toGraph()

# %%
# create a anomaly detection model
admodel = st.anomaly_detection.create(graph, st.ad_policy.HOLOSCOPE, "my_holoscope_model")

# %%
# run the model
admodel.run(k=3)
# Out:
# initial...
# Considering +[topology]
# matrix size: 500 x 497	#edges: 898.0
# alg: fastgreedy
# 	+ # of singlular vectors: 10
#
# initial start
# ::::Finish Init @  0.013579000000000008
# fast greedy algorithm ...
# process 1-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 20
# *** *** shaving opt value: 9.357241318860902
# === === improved opt size: 20
# === === improved opt value: 9.357241318860902
# process 2-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 131
# *** *** shaving opt value: 0.9924242424242424
# process 3-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 49
# *** *** shaving opt value: 0.98
# process 4-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 36
# *** *** shaving opt value: 0.972972972972973
# process 5-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 31
# *** *** shaving opt value: 0.9696969696969697
# process 6-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 29
# *** *** shaving opt value: 0.9700181870192568
# process 7-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .....
# *** *** shaving opt size: 25
# *** *** shaving opt value: 0.9615384615384616
# process 8-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 1
# *** *** shaving opt value: 0.5306883635849039
# process 9-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 16
# *** *** shaving opt value: 0.9418950041575332
# process 10-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 13
# *** *** shaving opt value: 0.9285714285714286
# ::::Finish Algorithm @  0.391807
# removing 20 rows from graph
# alg: fastgreedy
# 	+ # of singlular vectors: 10
#
# initial start
# ::::Finish Init @  0.007603000000000026
# fast greedy algorithm ...
# process 1-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 131
# *** *** shaving opt value: 0.9924242424242424
# === === improved opt size: 131
# === === improved opt value: 0.9924242424242424
# process 2-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 49
# *** *** shaving opt value: 0.98
# process 3-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 36
# *** *** shaving opt value: 0.972972972972973
# process 4-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 31
# *** *** shaving opt value: 0.9696969696969697
# process 5-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 29
# *** *** shaving opt value: 0.9700181870192568
# process 6-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 1
# *** *** shaving opt value: 0.5306883635849039
# process 7-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .....
# *** *** shaving opt size: 25
# *** *** shaving opt value: 0.9615384615384616
# process 8-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 16
# *** *** shaving opt value: 0.9418950041575332
# process 9-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 13
# *** *** shaving opt value: 0.9285714285714286
# process 10-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 12
# *** *** shaving opt value: 0.9230769230769231
# ::::Finish Algorithm @  0.38383900000000004
# removing 131 rows from graph
# alg: fastgreedy
# 	+ # of singlular vectors: 10
#
# initial start
# ::::Finish Init @  0.008345000000000269
# fast greedy algorithm ...
# process 1-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 49
# *** *** shaving opt value: 0.98
# === === improved opt size: 49
# === === improved opt value: 0.98
# process 2-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 36
# *** *** shaving opt value: 0.972972972972973
# process 3-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 31
# *** *** shaving opt value: 0.9696969696969697
# process 4-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 29
# *** *** shaving opt value: 0.9700181870192568
# process 5-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 1
# *** *** shaving opt value: 0.5306883635849039
# process 6-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .....
# *** *** shaving opt size: 25
# *** *** shaving opt value: 0.9615384615384616
# process 7-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 16
# *** *** shaving opt value: 0.9418950041575332
# process 8-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 13
# *** *** shaving opt value: 0.9285714285714286
# process 9-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 12
# *** *** shaving opt value: 0.9230769230769231
# process 10-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .
# *** *** shaving opt size: 16
# *** *** shaving opt value: 0.8888888888888888
# ::::Finish Algorithm @  0.2415759999999998
# global best size  20
# global best value  9.357241318860902
# block1:
# 	objective value 9.357241318860902
# block2:
# 	objective value 0.9924242424242424
# block3:
# 	objective value 0.98
