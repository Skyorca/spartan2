# %%
import spartan2.spartan as st

# %%
# set the computing engine
st.config(st.engine.SINGLEMACHINE)

# %%
# load graph data
data = st.loadTensor(name = "example", path = "inputData/", col_ids = ["uid", "oid", "timestamp", "rating"], col_types = [int, int, int, int])

# %%
# create a anomaly detection model
admodel = st.anomaly_detection.create(data, st.ad_policy.HOLOSCOPE, "my_holoscope_model")

# %%
# run the model
admodel.run(k=3)
# Out:
# initial...
# Considering +[topology]
# matrix size: 500 x 497	#edges: 898.0
# alg: fastgreedy
# 	+ # of singlular vectors: 10
#
# initial start
# ::::Finish Init @  0.012008
# fast greedy algorithm ...
# process 1-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ....................
# *** *** shaving opt size: 20
# *** *** shaving opt value: 9.35724131886
# === === improved opt size: 20
# === === improved opt value: 9.35724131886
# process 2-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ..................................................................
# *** *** shaving opt size: 131
# *** *** shaving opt value: 0.992424242424
# process 3-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .................................................
# *** *** shaving opt size: 49
# *** *** shaving opt value: 0.98
# process 4-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ....................................
# *** *** shaving opt size: 36
# *** *** shaving opt value: 0.972972972973
# process 5-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ...............................
# *** *** shaving opt size: 31
# *** *** shaving opt value: 0.969696969697
# process 6-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .............................
# *** *** shaving opt size: 29
# *** *** shaving opt value: 0.970018187019
# process 7-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .........................
# *** *** shaving opt size: 25
# *** *** shaving opt value: 0.961538461538
# process 8-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ..........................
# *** *** shaving opt size: 1
# *** *** shaving opt value: 0.530688363585
# process 9-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ................
# *** *** shaving opt size: 16
# *** *** shaving opt value: 0.941895004158
# process 10-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .............
# *** *** shaving opt size: 13
# *** *** shaving opt value: 0.928571428571
# ::::Finish Algorithm @  1.009782
# removing 20 rows from graph
# alg: fastgreedy
# 	+ # of singlular vectors: 10
#
# initial start
# ::::Finish Init @  0.012162
# fast greedy algorithm ...
# process 1-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ..................................................................
# *** *** shaving opt size: 131
# *** *** shaving opt value: 0.992424242424
# === === improved opt size: 131
# === === improved opt value: 0.992424242424
# process 2-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .................................................
# *** *** shaving opt size: 49
# *** *** shaving opt value: 0.98
# process 3-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ....................................
# *** *** shaving opt size: 36
# *** *** shaving opt value: 0.972972972973
# process 4-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ...............................
# *** *** shaving opt size: 31
# *** *** shaving opt value: 0.969696969697
# process 5-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .............................
# *** *** shaving opt size: 29
# *** *** shaving opt value: 0.970018187019
# process 6-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ..........................
# *** *** shaving opt size: 1
# *** *** shaving opt value: 0.530688363585
# process 7-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .........................
# *** *** shaving opt size: 25
# *** *** shaving opt value: 0.961538461538
# process 8-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ................
# *** *** shaving opt size: 16
# *** *** shaving opt value: 0.941895004158
# process 9-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .............
# *** *** shaving opt size: 13
# *** *** shaving opt value: 0.928571428571
# process 10-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ............
# *** *** shaving opt size: 12
# *** *** shaving opt value: 0.923076923077
# ::::Finish Algorithm @  1.040427
# removing 131 rows from graph
# alg: fastgreedy
# 	+ # of singlular vectors: 10
#
# initial start
# ::::Finish Init @  0.011771
# fast greedy algorithm ...
# process 1-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .................................................
# *** *** shaving opt size: 49
# *** *** shaving opt value: 0.98
# === === improved opt size: 49
# === === improved opt value: 0.98
# process 2-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ....................................
# *** *** shaving opt size: 36
# *** *** shaving opt value: 0.972972972973
# process 3-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ...............................
# *** *** shaving opt size: 31
# *** *** shaving opt value: 0.969696969697
# process 4-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .............................
# *** *** shaving opt size: 29
# *** *** shaving opt value: 0.970018187019
# process 5-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ..........................
# *** *** shaving opt size: 1
# *** *** shaving opt value: 0.530688363585
# process 6-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .........................
# *** *** shaving opt size: 25
# *** *** shaving opt value: 0.961538461538
# process 7-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ................
# *** *** shaving opt size: 16
# *** *** shaving opt value: 0.941895004158
# process 8-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# .............
# *** *** shaving opt size: 13
# *** *** shaving opt value: 0.928571428571
# process 9-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ............
# *** *** shaving opt size: 12
# *** *** shaving opt value: 0.923076923077
# process 10-th singular vector
# *** *** shaving ...
# set up the greedy min tree
# ................
# *** *** shaving opt size: 16
# *** *** shaving opt value: 0.888888888889
# ::::Finish Algorithm @  0.681517
# global best size  20
# global best value  9.357241318860902
# block1:
# 	objective value 9.35724131886
# block2:
# 	objective value 0.992424242424
# block3:
# 	objective value 0.98
